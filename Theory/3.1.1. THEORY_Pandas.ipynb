# %% [markdown]
# # 3. Pandas
# -----

# %% [markdown]
# ## 3.1. DataFrame creation

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(
    {
        'a': np.random.randint(1, 100, size=20),
        'b': np.random.randint(1, 100, size=20),
        'c': np.random.randint(1, 100, size=20)
    }
)
df
# Out:
#      a   b   c
# 0   60  99  11
# 1   72  13  58
# 2   19  74  68
# 3   91  38  45
# 4   80  74  49
# 5   80  76  19
# 6   71  32   1
# 7   86  89  86
# 8   94  30  38
# 9   82  99  94
# 10  55  66  16
# 11  10  66  34
# 12  78  57  88
# 13  27  69  14
# 14  34  78  60
# 15  76  30  17
# 16   2  58  83
# 17  15  88  50
# 18  18  65  22
# 19  41  88  87

# %%
a_col = df["a"]
a_col

for i in df["a"]:
    print(i)
# Out:
# 60
# 72
# 19
# 91
# 80
# 80
# 71
# 86
# 94
# 82
# 55
# 10
# 78
# 27
# 34
# 76
# 2
# 15
# 18
# 41

# %%
df.sort_index(axis=0, ascending=False)
# Out:
#      a   b   c
# 19  41  88  87
# 18  18  65  22
# 17  15  88  50
# 16   2  58  83
# 15  76  30  17
# 14  34  78  60
# 13  27  69  14
# 12  78  57  88
# 11  10  66  34
# 10  55  66  16
# 9   82  99  94
# 8   94  30  38
# 7   86  89  86
# 6   71  32   1
# 5   80  76  19
# 4   80  74  49
# 3   91  38  45
# 2   19  74  68
# 1   72  13  58
# 0   60  99  11

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#      c   b   a
# 0   11  99  60
# 1   58  13  72
# 2   68  74  19
# 3   45  38  91
# 4   49  74  80
# 5   19  76  80
# 6    1  32  71
# 7   86  89  86
# 8   38  30  94
# 9   94  99  82
# 10  16  66  55
# 11  34  66  10
# 12  88  57  78
# 13  14  69  27
# 14  60  78  34
# 15  17  30  76
# 16  83  58   2
# 17  50  88  15
# 18  22  65  18
# 19  87  88  41

# %%
df
# Out:
#      a   b   c
# 0   60  99  11
# 1   72  13  58
# 2   19  74  68
# 3   91  38  45
# 4   80  74  49
# 5   80  76  19
# 6   71  32   1
# 7   86  89  86
# 8   94  30  38
# 9   82  99  94
# 10  55  66  16
# 11  10  66  34
# 12  78  57  88
# 13  27  69  14
# 14  34  78  60
# 15  76  30  17
# 16   2  58  83
# 17  15  88  50
# 18  18  65  22
# 19  41  88  87

# %%
df.sort_values(by='b', axis=0)
# Out:
#      a   b   c
# 1   72  13  58
# 8   94  30  38
# 15  76  30  17
# 6   71  32   1
# 3   91  38  45
# 12  78  57  88
# 16   2  58  83
# 18  18  65  22
# 10  55  66  16
# 11  10  66  34
# 13  27  69  14
# 2   19  74  68
# 4   80  74  49
# 5   80  76  19
# 14  34  78  60
# 19  41  88  87
# 17  15  88  50
# 7   86  89  86
# 0   60  99  11
# 9   82  99  94

# %%
df
# Out:
#      a   b   c
# 0   60  99  11
# 1   72  13  58
# 2   19  74  68
# 3   91  38  45
# 4   80  74  49
# 5   80  76  19
# 6   71  32   1
# 7   86  89  86
# 8   94  30  38
# 9   82  99  94
# 10  55  66  16
# 11  10  66  34
# 12  78  57  88
# 13  27  69  14
# 14  34  78  60
# 15  76  30  17
# 16   2  58  83
# 17  15  88  50
# 18  18  65  22
# 19  41  88  87

# %%
mask_on_a = (df['a'] > 25)
mask_on_b = (df['b'] > 90)

df[mask_on_a & mask_on_b]
# Out:
#     a   b   c
# 0  60  99  11
# 9  82  99  94

# %%
df > 25
# Out:
#         a      b      c
# 0    True   True  False
# 1    True  False   True
# 2   False   True   True
# 3    True   True   True
# 4    True   True   True
# 5    True   True  False
# 6    True   True  False
# 7    True   True   True
# 8    True   True   True
# 9    True   True   True
# 10   True   True  False
# 11  False   True   True
# 12   True   True   True
# 13   True   True  False
# 14   True   True   True
# 15   True   True  False
# 16  False   True   True
# 17  False   True   True
# 18  False   True  False
# 19   True   True   True

# %%
mask_on_a
# Out:
# 0      True
# 1      True
# 2     False
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11    False
# 12     True
# 13     True
# 14     True
# 15     True
# 16    False
# 17    False
# 18    False
# 19     True
# Name: a, dtype: bool

# %%
mask_on_b
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# Name: b, dtype: bool

# %%
mask = (df['a'] > 25) | (df['b'] > 50)
df[mask]
# Out:
#      a   b   c
# 0   60  99  11
# 1   72  13  58
# 2   19  74  68
# 3   91  38  45
# 4   80  74  49
# 5   80  76  19
# 6   71  32   1
# 7   86  89  86
# 8   94  30  38
# 9   82  99  94
# 10  55  66  16
# 11  10  66  34
# 12  78  57  88
# 13  27  69  14
# 14  34  78  60
# 15  76  30  17
# 16   2  58  83
# 17  15  88  50
# 18  18  65  22
# 19  41  88  87

# %%
df.mean()
# Out:
# a    54.55
# b    64.45
# c    47.00
# dtype: float64

# %% [markdown]
# ## 3.2. Basic Pandas functions

# %%
df.head(3)
# Out:
#     a   b   c
# 0  60  99  11
# 1  72  13  58
# 2  19  74  68

# %%
df.tail(5)
# Out:
#      a   b   c
# 15  76  30  17
# 16   2  58  83
# 17  15  88  50
# 18  18  65  22
# 19  41  88  87

# %% [markdown]
# One way to quickly see the most important statistics of the dataframe

# %%
df.describe()
# Out:
#                a          b         c
# count  20.000000  20.000000  20.00000
# mean   54.550000  64.450000  47.00000
# std    30.619009  24.596694  29.97894
# min     2.000000  13.000000   1.00000
# 25%    25.000000  52.250000  18.50000
# 50%    65.500000  67.500000  47.00000
# 75%    80.000000  80.500000  71.75000
# max    94.000000  99.000000  94.00000

# %%
df.shape
# Out:
# (20, 3)

# %%
df.a.unique()
# Out:
# array([60, 72, 19, 91, 80, 71, 86, 94, 82, 55, 10, 78, 27, 34, 76,  2, 15,
#        18, 41])

# %%
df.a.nunique()
# Out:
# 19

# %%
df.a.sum()
# Out:
# 1091

# %%
df.sum()
# Out:
# a    968
# b    932
# c    933
# dtype: int64

# %%
df.min()
# Out:
# a    4
# b    1
# c    5
# dtype: int32

# %%
df.mean()
# Out:
# a    48.40
# b    46.60
# c    46.65
# dtype: float64

# %% [markdown]
# ## 3.3. Column creation

# %%
df['a * b'] = df.a * df.b
df
# Out:
#      a   b   c  a * b
# 0   62  15  22    930
# 1   21  81  16   1701
# 2   92  17  97   1564
# 3   82   8  49    656
# 4   25   1  75     25
# 5    9  13  52    117
# 6    4   2  17      8
# 7   55   8  30    440
# 8    8   4   8     32
# 9   83  93  91   7719
# 10  25  85  22   2125
# 11  19  75  69   1425
# 12  78  99  35   7722
# 13  24  74   5   1776
# 14  90  72  37   6480
# 15  29  74  73   2146
# 16  85  37  52   3145
# 17  57  69  39   3933
# 18  77  90  75   6930
# 19  43  15  69    645

# %% [markdown]
# ## 3.4. Boolean filtering

# %%
df = df[df['a * b'] > 3000]
df
# Out:
#      a   b   c  a * b
# 9   83  93  91   7719
# 12  78  99  35   7722
# 14  90  72  37   6480
# 16  85  37  52   3145
# 17  57  69  39   3933
# 18  77  90  75   6930

# %% [markdown]
# Indexing the dataframe

# %% [markdown]
# ## 3.5. DataFrame indexing

# %%
df = pd.DataFrame(
    {
        'name': ['Peter', 'Juan', 'Melisa', 'Ana', 'Charles', 'Maria', 'Sonia', 'Peter', 'Melisa', 'Ana', 'Ana'],
        'age': [23, 20, 34, 40, 45, 21, 67, 55, 89, 3, 14]
    }
)
display(df.iloc[:4])
display(df.iloc[4:])
display(df.iloc[1:3, :])
display(df.loc[:2])
display(df.iloc[2])
display(df.iloc[[1, 2, 3], 1])
# Out:
#      name  age
# 0   Peter   23
# 1    Juan   20
# 2  Melisa   34
# 3     Ana   40
#        name  age
# 4   Charles   45
# 5     Maria   21
# 6     Sonia   67
# 7     Peter   55
# 8    Melisa   89
# 9       Ana    3
# 10      Ana   14
#      name  age
# 1    Juan   20
# 2  Melisa   34
#      name  age
# 0   Peter   23
# 1    Juan   20
# 2  Melisa   34
# name    Melisa
# age         34
# Name: 2, dtype: object
# 1    20
# 2    34
# 3    40
# Name: age, dtype: int64

# %% [markdown]
# ## 3.6. Basic columns operations

# %%
df = pd.DataFrame(
    {
        'name': ['Peter', 'Juan', 'Melisa', 'Ana', 'Charles', 'Maria', 'Sonia', 'Peter', 'Melisa', 'Ana', 'Ana'],
        'age': [23, 20, 34, 40, 45, 21, 67, 55, 89, 3, 14]
    }
)
df
# Out:
#        name  age
# 0     Peter   23
# 1      Juan   20
# 2    Melisa   34
# 3       Ana   40
# 4   Charles   45
# 5     Maria   21
# 6     Sonia   67
# 7     Peter   55
# 8    Melisa   89
# 9       Ana    3
# 10      Ana   14

# %%
df.groupby(['name']).mean()
# Out:
#           age
# name
# Ana      19.0
# Charles  45.0
# Juan     20.0
# Maria    21.0
# Melisa   61.5
# Peter    39.0
# Sonia    67.0

# %%
df.groupby(['name']).sum()
# Out:
#          age
# name
# Ana       57
# Charles   45
# Juan      20
# Maria     21
# Melisa   123
# Peter     78
# Sonia     67

# %% [markdown]
# ## 3.7. Column renaming

# %%
df = pd.DataFrame(
    {
        'name': ['Peter', 'Juan', 'Melisa', 'Ana', 'Charles', 'Maria', 'Sonia', 'Peter', 'Melisa', 'Ana', 'Ana'],
        'age': [23, 20, 34, 40, 45, 21, 67, 55, 89, 3, 14]
    }
)
display(df)

df = df.rename(columns={'name': 'NOMBRE'})
df
# Out:
#        name  age
# 0     Peter   23
# 1      Juan   20
# 2    Melisa   34
# 3       Ana   40
# 4   Charles   45
# 5     Maria   21
# 6     Sonia   67
# 7     Peter   55
# 8    Melisa   89
# 9       Ana    3
# 10      Ana   14
#      NOMBRE  age
# 0     Peter   23
# 1      Juan   20
# 2    Melisa   34
# 3       Ana   40
# 4   Charles   45
# 5     Maria   21
# 6     Sonia   67
# 7     Peter   55
# 8    Melisa   89
# 9       Ana    3
# 10      Ana   14

# %% [markdown]
# ## 3.8. Sorting

# %%
df.sort_values(by='age', ascending=True)
# Out:
#      NOMBRE  age
# 9       Ana    3
# 10      Ana   14
# 1      Juan   20
# 5     Maria   21
# 0     Peter   23
# 2    Melisa   34
# 3       Ana   40
# 4   Charles   45
# 7     Peter   55
# 6     Sonia   67
# 8    Melisa   89

# %% [markdown]
# ## 3.9. Pandas Concat, Join and Merge

# %%
df_1 = pd.DataFrame(
    {
        'name': ['Peter', 'Juan', 'Melisa', 'Ana', 'Charles', 'Maria', 'Sonia', 'Peter', 'Melisa', 'Ana', 'Ana'],
        'age': [23, 20, 34, 40, 45, 21, 67, 55, 89, 3, 14]
    }
)

df_2 = pd.DataFrame(
    {
        'country': ['Chile', 'Peru', 'USA', 'USA', 'Russia', 'France', 'Argentina', 'Australia', 'Mexico', 'Mexico', 'Spain'],
    }
)

df_3 = pd.DataFrame(
    {
        'name': ['Martin', 'Lucia', 'Agatha'],
        'age': [33, 65, 11]
    }
)

df_4 = pd.DataFrame(
    {
        'name': ['Peter', 'Juan', 'Melisa', 'Ana', 'Charles', 'Maria', 'Sonia', 'Peter', 'Melisa', 'Ana', 'Ana'],
        'country': ['Chile', 'Peru', 'USA', 'USA', 'Russia', 'France', 'Argentina', 'Australia', 'Mexico', 'Mexico', 'Spain'],
    }
)

df_concat = pd.concat([df_1, df_3])
df_concat
# Out:
#        name  age
# 0     Peter   23
# 1      Juan   20
# 2    Melisa   34
# 3       Ana   40
# 4   Charles   45
# 5     Maria   21
# 6     Sonia   67
# 7     Peter   55
# 8    Melisa   89
# 9       Ana    3
# 10      Ana   14
# 0    Martin   33
# 1     Lucia   65
# 2    Agatha   11

# %%
df_1.join(df_2)
# Out:
#        name  age    country
# 0     Peter   23      Chile
# 1      Juan   20       Peru
# 2    Melisa   34        USA
# 3       Ana   40        USA
# 4   Charles   45     Russia
# 5     Maria   21     France
# 6     Sonia   67  Argentina
# 7     Peter   55  Australia
# 8    Melisa   89     Mexico
# 9       Ana    3     Mexico
# 10      Ana   14      Spain

# %%
df_merge = pd.merge(df_1, df_4, on='name', how="outer")
df_merge
# Out:
#        name  age    country
# 0     Peter   23      Chile
# 1     Peter   23  Australia
# 2     Peter   55      Chile
# 3     Peter   55  Australia
# 4      Juan   20       Peru
# 5    Melisa   34        USA
# 6    Melisa   34     Mexico
# 7    Melisa   89        USA
# 8    Melisa   89     Mexico
# 9       Ana   40        USA
# 10      Ana   40     Mexico
# 11      Ana   40      Spain
# 12      Ana    3        USA
# 13      Ana    3     Mexico
# 14      Ana    3      Spain
# 15      Ana   14        USA
# 16      Ana   14     Mexico
# 17      Ana   14      Spain
# 18  Charles   45     Russia
# 19    Maria   21     France
# 20    Sonia   67  Argentina

# %%
df_1.join(df_4)

# %% [markdown]
# ## 3.10. Working with datetime

# %%
df = pd.DataFrame(
    {
        'date': ['2022-2-10 18:30:0', '2021-7-1 9:45:30', '2015-11-12 4:55:1'],
        'value': [2, 3, 4]
    }
)

# See See strftime documentation for more information on format choices:
# https://docs.python.org/3/library/datetime.html#strftime-and-strptime-format-codes.
df['date'] = pd.to_datetime(df['date'], format="%Y-%d-%m %H:%M:%S")
display(df)
# Out:
#                  date  value
# 0 2022-10-02 18:30:00      2
# 1 2021-01-07 09:45:30      3
# 2 2015-12-11 04:55:01      4

# %%
df['year']= df['date'].dt.year
df['month']= df['date'].dt.month
df['day']= df['date'].dt.day
display(df)
# Out:
#                  date  value  year  month  day
# 0 2022-10-02 18:30:00      2  2022     10    2
# 1 2021-01-07 09:45:30      3  2021      1    7
# 2 2015-12-11 04:55:01      4  2015     12   11

# %%
# isocalendar() returns a 3-tuple containing ISO year, week number, and weekday
df['week_of_year'] = df['date'].dt.isocalendar().week
df['day_of_week'] = df['date'].dt.dayofweek
# A leap year is a year, which has 366 days (instead of 365)
df['is_leap_year'] = df['date'].dt.is_leap_year
display(df)
# Out:
#                  date  value  year  month  day  week_of_year  day_of_week  \
# 0 2022-10-02 18:30:00      2  2022     10    2            39            6
# 1 2021-01-07 09:45:30      3  2021      1    7             1            3
# 2 2015-12-11 04:55:01      4  2015     12   11            50            4
#
#    is_leap_year
# 0         False
# 1         False
# 2         False

# %%
mapping = {
    0: 'Monday', 
    1: 'Tuesday', 
    2: 'Wednesday', 
    3: 'Thursday', 
    4: 'Friday',
    5: 'Saturday', 
    6: 'Sunday'
} 
df['day_of_week_name'] = df['date'].dt.weekday.map(mapping)
display(df)
# Out:
#                  date  value  year  month  day  week_of_year  day_of_week  \
# 0 2022-10-02 18:30:00      2  2022     10    2            39            6
# 1 2021-01-07 09:45:30      3  2021      1    7             1            3
# 2 2015-12-11 04:55:01      4  2015     12   11            50            4
#
#    is_leap_year day_of_week_name
# 0         False           Sunday
# 1         False         Thursday
# 2         False           Friday

# %%
today = pd.to_datetime('today')
df['age'] = today.year - df['date'].dt.year
display(df)
# Out:
#                  date  value  year  month  day  week_of_year  day_of_week  \
# 0 2022-10-02 18:30:00      2  2022     10    2            39            6
# 1 2021-01-07 09:45:30      3  2021      1    7             1            3
# 2 2015-12-11 04:55:01      4  2015     12   11            50            4
#
#    is_leap_year day_of_week_name  age
# 0         False           Sunday    0
# 1         False         Thursday    1
# 2         False           Friday    7

# %%
condition = (df['date'] > '2016-7-1 9:45:30') & (df['date'] <= today)
display(df.loc[condition])
# Out:
#                  date  value  year  month  day  week_of_year  day_of_week  \
# 1 2021-01-07 09:45:30      3  2021      1    7             1            3
#
#    is_leap_year day_of_week_name  age
# 1         False         Thursday    1

# %%
print(df.date[0] - df.date[1])
# Out:
# 633 days 08:44:30

# %% [markdown]
# ## 3.11. Iterating over a pandas dataframe

# %%
df = pd.DataFrame(
    {
        'name': ['Peter', 'Juan', 'Melisa', 'Ana', 'Charles', 'Maria', 'Sonia', 'Peter', 'Melisa', 'Ana', 'Ana'],
        'age': [23, 20, 34, 40, 45, 21, 67, 55, 89, 3, 14]
    }
)

amount_of_months = []
for idx, row in df.iterrows():
    amount_of_months.append(row['age'] * 12)

df['amount_of_months'] = amount_of_months
df
# Out:
#        name  age  amount_of_months
# 0     Peter   23               276
# 1      Juan   20               240
# 2    Melisa   34               408
# 3       Ana   40               480
# 4   Charles   45               540
# 5     Maria   21               252
# 6     Sonia   67               804
# 7     Peter   55               660
# 8    Melisa   89              1068
# 9       Ana    3                36
# 10      Ana   14               168

# %% [markdown]
# ## 3.12. Pandas plot

# %%
import numpy as np
import pandas as pd

ts = pd.Series(
    np.random.randn(1000),
    index=pd.date_range("1/1/2000", periods=1000)
)

ts = ts.cumsum()
ts.plot();

# %%
df = pd.DataFrame(
    {
        'a': np.random.randint(1, 100, size=30),
        'b': np.random.randint(1, 100, size=30),
        'c': np.random.randint(1, 100, size=30)
    }
)
df.plot();

# %%
df = pd.DataFrame(
    {
        'a': np.random.randint(1, 100, size=30),
        'b': np.random.randint(1, 100, size=30),
        'c': np.random.randint(1, 100, size=30)
    }
)
df['a'].plot();
